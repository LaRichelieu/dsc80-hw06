# %% [markdown]
# # DSC 80: Homework 06
#
# ### Due Date: Monday, Feb 18 12:00PM

# %% [markdown]
# ## Instructions
# Much like in DSC 10, this Jupyter Notebook contains the statements of the homework problems and provides code and markdown cells to display your answers to the problems. Unlike DSC 10, the notebook is *only* for displaying a readable version of your final answers. The coding work will be developed in an accompanying `hw0X.py` file, that will be imported into the current notebook. (`X` is a homework number)
#
# Homeworks and programming assignments will be graded in (at most) two ways:
# 1. The functions and classes in the accompanying python file will be tested (a la DSC 20),
# 2. The notebook will be graded (for graphs and free response questions).
#
#
# **Do not change the function names in the `*.py` file**
# - The functions in the `*.py` file are how your assignment is graded, and they are graded by their name. The dictionary at the end of the file (`GRADED FUNCTIONS`) contains the "grading list". The final function in the file allows your doctests to check that all the necessary functions exist.
# - If you changed something you weren't supposed to, just use git to revert!
#
# **Tips for working in the Notebook**:
# - The notebooks serve to present you the questions and give you a place to present your results for later review.
# - The notebook on *HW assignments* are not graded (only the `.py` file).
# - Notebooks for PAs will serve as a final report for the assignment, and contain conclusions and answers to open ended questions that are graded.
# - The notebook serves as a nice environment for 'pre-development' and experimentation before designing your function in your `.py` file.
#
# **Tips for developing in the .py file**:
# - Do not change the function names in the starter code; grading is done using these function names.
# - Do not change the docstrings in the functions. These are there to tell you if your work is on the right track!
# - You are encouraged to write your own additional functions to solve the HW!
#     - Developing in python usually consists of larger files, with many short functions.
#     - You may write your other functions in an additional `.py` file that you import in `hw0X.py` (much like we do in the notebook).
# - Always document your code!

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import hw06 as hw

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import time

# %%
import requests
import bs4

# %% [markdown]
# # Basic HTML tags practice
#
# **Question 1**
#
# Create a very basic `html` file that satisfies the following properties:
#
# 1. Has `<head>` and `<body>` tags.
# 2. Has a title
# 3. Inside the body tags:
#     * At least two headers
#     * At least three images:
#         * At least one image must be a local file
#         * At least one image must be linked to on-line source
#     * At least three references
#     * At least one table with two columns.
#
# 4. Save your work as `hw06_1.html` in the same directory as `hw06.py`, make sure it loads in the browser and do not forget to submit it.
# 5. Do not forget to submit all data files needed to display your page.
#
# **Note:** You can toy with (basic) HTML in the cells of a notebook, using either a "markdown cell" or by using the `IPython.display.HTML` function. However, be sure to open your saved file in a browser to be sure the page displays properly!

# %% [markdown]
# <html>
#     <head>
#         <title>hw06-1.html</title>
#     </head>
#     <body>
#         <div id="content">
#             <h1>DSC 80</h1>
#             <p>This is a hard course</p>
#             <hr>
#         </div>
#         <div id="questions">
#             <h2>HW06 Questions</h2>
#             <ul>
#                 <li>Question 1</li>
#                 <li>Question 2</li>
#                 <li>Question 3</li>
#                 <li>Question 4</li>
#                 <li>Question 5</li>
#             </ul>
#             <h2>Number of Questions</h2>
#             <table>
#                 <tr>
#                     <th>Question #</th>
#                     <th>Number of Questions</th>
#                 </tr>
#                 <tr>
#                     <th>1</th>
#                     <th>1</th>
#                 </tr>
#                 <tr>
#                     <th>2</th>
#                     <th>5</th>
#                 </tr>
#                 <tr>
#                     <th>3</th>
#                     <th>2</th>
#                 </tr>
#                 <tr>
#                     <th>4</th>
#                     <th>3</th>
#                 </tr>
#                 <tr>
#                     <th>5</th>
#                     <th>3</th>
#                 </tr>
#             </table>
#             <hr>
#         </div>
#         <div id="resource">
#             <h2>Useful Sources</h2>
#             <a href="https://piazza.com">Piazza</a>
#             <a href="https://sites.google.com/view/dsc-80-winter-2019/links-and-resources">Course Website</a>
#             <a href="https://www.gradescope.com/">Gradescope</a>
#             <hr>
#         </div>
#         <div id="images">
#             <h2>Some Images</h2>
#             <h4>Q4 Data</h4>
#             <img src="bookdata.png" alt="Unable to show">
#             <h4>Pride and Prejudice</h4>
#             <img src="https://upload.wikimedia.org/wikipedia/commons/1/17/PrideAndPrejudiceTitlePage.jpg" alt="Unable to show">
#             <h4>New York Times</h4>
#             <img src="https://upload.wikimedia.org/wikipedia/en/6/66/NewYorkTimesFrontPage-15Nov2012.jpg" alt="Unable to show">
#         </div>
#     </body>
# </html>

# %% [markdown]
# # I'm ready for scraping! But am I allowed to?
#
# **Question 2**
#
# We know that many sites have a published policy allowing or disallowing automatic access to their site. Often, this policy is in a text file `robots.txt`. There is (`https://moz.com/learn/seo/robotstxt`) a good article that explains what these files are, where to find them, and how to use them. After reading the article please answer a few questions.
#
# **2.1: What is the purpose of `robots.txt`?**
#
# 1) To informs agents which pages to crawl.
#
# 2) To informs agents that the site is automated.
#
# 3) To inform agents that robots will chase them down if their info is stolen.
#
# **2.2: Where do you put your `robots.txt` file?**
#
# 1) In the folder you want to disallow.
#
# 2) In the root directory of your website.
#
# 3) In a Google search.
#
#
# **2.3: If a `robots.txt` is not present, does it mean you can safely scrape the site?**
#
# 1) Yes
#
# 2) No
#
# **2.4: Each subdomain on a root domain can use separate `robots.txt` file**
#
# 1) Yes
#
# 2) No
#
#
# **2.5: Website hunt**
#
# Next, find three websites that explicitly use a `robots.txt` file and allow scraping and three that do not allow it.
#
#
# Now combine you answers to multiple choice questions in one list and urls of the sites you found in another list.
# Create an argument-free function `answers` to return both of lists.

# %% [markdown]
# # Count counties that start with different letters.
#
# **Question 3**
#
# In this question you need to scrape the website `http://example.webscraping.com/` and collect the data on all countries (not just the first page). I recommend you to check the website first, count the number of pages you need to go over, look at the URL of each page etc. Make sure to check the source page of the website in order to find appropriate tags for you to use during the scraping.
#
# Once you have an idea how the site works, you can start sending requests to the pages and collect results.
#
# *Side note:* We saw in the lecture that there is a method `pd.read_html` that allows you to read HTML tables into a list of DataFrame objects. You can test it out but please **DO NOT** use it in your solution. The purpose of this problem is for you to practice scraping using simple tags first, before you move on to more difficult problems.
#
#
# 1. Create a function `find_countries` that takes in an url and return a dataframe with a single column that lists all countries from the given site.
#
# 2. Create another function `first_letters_count` that takes in a dataframe with the list of countries and return another dataframe, indexed by a capital letter and the column containing the number of countries starting from this letter. That is, X countries start with an "A", Y countries start with a "B" etc.  Sort the column in decreasing order (by value).

# %% [markdown]
# **Note: You must uncomment the doctests for this question to run them.** Please use the doctests for this question sparingly; every time you run them, it will scrape this page multiple times.
# 1. Uncomment them only when you think you are done with the question,
# 2. Replace the comments when you work further on other questions,
# 3. Uncomment them lastly when you submit to gradescope.

# %%
url = "http://example.webscraping.com/"

# %%
fp = os.path.join('data', 'countries-sample.csv')
df = pd.read_csv(fp)

# %%
df.loc[:,'Start Letter'] = df.iloc[:,0].apply(lambda x: x[0:1])

# %%
unsorted = df[['Countries', 'Start Letter']].groupby('Start Letter').count()

# %%
unsorted.sort_values(unsorted.columns[0], ascending = False)
# Out:
#               Countries
# Start Letter
# S                     3
# M                     2
# D                     1
# G                     1
# P                     1
# T                     1
# Z                     1

# %% [markdown]
# # Scraping an Online Bookstore

# %% [markdown]
# **Question 4**
#
# Browse through the following fake on-line bookstore: http://books.toscrape.com/. This website is meant for toying with scraping.
#
# Scrape the website, collecting data on all books that have *at least* a four-star rating and are *under* £20. You should collect the data in a dataframe as below:
#
# <img src="bookdata.png">
#
# Do this using the following steps:
# 1. Create a function `extract_book_links` that takes in the content of a book-listing page (a string of html) and returns a list of urls of book-detail pages from which to scrape data.
# 2. Create a function `get_product_info` that takes in the content of a book-detail page (a string of html) and returns a dictionary corresponding to a row in the dataframe in the image above.
# 3. Create a function `scrape_books` of a single variable `k` that scrapes the first `k` pages of the bookstore (as determined by starting at the url above and clicking on the 'next' button), and returns a dataframe of books as described above.
#
# *Note:* Your function should take under 60 seconds to run through the entire bookstore.

# %%
hw.scrape_books(50)
# Out:
#                Availability Number of reviews Price (excl. tax)  \
# 0   In stock (19 available)                 0           Â£17.46
# 1   In stock (18 available)                 0           Â£17.66
# 2   In stock (18 available)                 0           Â£15.94
# 3   In stock (16 available)                 0           Â£14.27
# 4   In stock (16 available)                 0           Â£19.49
# 5   In stock (16 available)                 0           Â£17.27
# 6   In stock (16 available)                 0           Â£13.61
# 7   In stock (16 available)                 0           Â£13.34
# 8   In stock (16 available)                 0           Â£15.44
# 9   In stock (16 available)                 0           Â£14.02
# 10  In stock (16 available)                 0           Â£15.97
# 11  In stock (16 available)                 0           Â£17.08
# 12  In stock (15 available)                 0           Â£12.61
# 13  In stock (15 available)                 0           Â£17.44
# 14  In stock (15 available)                 0           Â£16.24
# 15  In stock (15 available)                 0           Â£14.19
# 16  In stock (15 available)                 0           Â£19.19
# 17  In stock (15 available)                 0           Â£15.38
# 18  In stock (15 available)                 0           Â£12.51
# 19  In stock (14 available)                 0           Â£12.96
# 20  In stock (14 available)                 0           Â£11.89
# 21  In stock (14 available)                 0           Â£11.83
# 22  In stock (14 available)                 0           Â£16.28
# 23  In stock (14 available)                 0           Â£10.60
# 24  In stock (14 available)                 0           Â£14.75
# 25  In stock (14 available)                 0           Â£10.23
# 26  In stock (14 available)                 0           Â£15.06
# 27  In stock (14 available)                 0           Â£14.39
# 28  In stock (14 available)                 0           Â£11.21
# 29  In stock (14 available)                 0           Â£11.23
# ..                      ...               ...               ...
# 45   In stock (6 available)                 0           Â£15.42
# 46   In stock (6 available)                 0           Â£19.27
# 47   In stock (5 available)                 0           Â£15.08
# 48   In stock (5 available)                 0           Â£11.05
# 49   In stock (5 available)                 0           Â£11.33
# 50   In stock (5 available)                 0           Â£16.23
# 51   In stock (5 available)                 0           Â£15.52
# 52   In stock (5 available)                 0           Â£17.49
# 53   In stock (5 available)                 0           Â£10.00
# 54   In stock (5 available)                 0           Â£17.21
# 55   In stock (4 available)                 0           Â£16.81
# 56   In stock (4 available)                 0           Â£13.73
# 57   In stock (4 available)                 0           Â£19.67
# 58   In stock (4 available)                 0           Â£12.75
# 59   In stock (3 available)                 0           Â£13.03
# 60   In stock (3 available)                 0           Â£14.57
# 61   In stock (3 available)                 0           Â£12.91
# 62   In stock (3 available)                 0           Â£19.07
# 63   In stock (3 available)                 0           Â£10.79
# 64   In stock (3 available)                 0           Â£15.36
# 65   In stock (3 available)                 0           Â£15.28
# 66   In stock (3 available)                 0           Â£14.08
# 67   In stock (2 available)                 0           Â£12.86
# 68   In stock (2 available)                 0           Â£11.64
# 69   In stock (1 available)                 0           Â£18.51
# 70   In stock (1 available)                 0           Â£19.69
# 71   In stock (1 available)                 0           Â£12.34
# 72   In stock (1 available)                 0           Â£12.29
# 73   In stock (1 available)                 0           Â£19.18
# 74   In stock (1 available)                 0           Â£16.97
#
#    Price (incl. tax) Product Type     Tax               UPC  \
# 0            Â£17.46        Books  Â£0.00  ce6396b0f23f6ecc
# 1            Â£17.66        Books  Â£0.00  6258a1f6a6dcfe50
# 2            Â£15.94        Books  Â£0.00  6be3beb0793a53e7
# 3            Â£14.27        Books  Â£0.00  657fe5ead67a7767
# 4            Â£19.49        Books  Â£0.00  51653ef291ab7ddc
# 5            Â£17.27        Books  Â£0.00  709822d0b5bcb7f4
# 6            Â£13.61        Books  Â£0.00  0fa6dceead7ce47a
# 7            Â£13.34        Books  Â£0.00  0e691eda369f4e09
# 8            Â£15.44        Books  Â£0.00  889139b8e9c4cb36
# 9            Â£14.02        Books  Â£0.00  72f9d5be3472d34e
# 10           Â£15.97        Books  Â£0.00  9e28048cea8d41f7
# 11           Â£17.08        Books  Â£0.00  7b599c8bfcdd8d30
# 12           Â£12.61        Books  Â£0.00  3bebf34ee9330cbd
# 13           Â£17.44        Books  Â£0.00  f5a92cff83897d48
# 14           Â£16.24        Books  Â£0.00  ca71e72655bece85
# 15           Â£14.19        Books  Â£0.00  31001a1210623bd4
# 16           Â£19.19        Books  Â£0.00  88c21fcd38e2486e
# 17           Â£15.38        Books  Â£0.00  47271d8e08b5d31c
# 18           Â£12.51        Books  Â£0.00  d195e7f4ed697350
# 19           Â£12.96        Books  Â£0.00  6a31307a81e8f3a8
# 20           Â£11.89        Books  Â£0.00  ac8e3949d284e9a9
# 21           Â£11.83        Books  Â£0.00  02b74068fa98d8a4
# 22           Â£16.28        Books  Â£0.00  708345c9897fd7c5
# 23           Â£10.60        Books  Â£0.00  aeff7b87a8e83ebb
# 24           Â£14.75        Books  Â£0.00  fbb21a2f71f4d981
# 25           Â£10.23        Books  Â£0.00  f201f263d8c23f97
# 26           Â£15.06        Books  Â£0.00  ac4dde0d1be05de0
# 27           Â£14.39        Books  Â£0.00  1d6dd0c87d90fe92
# 28           Â£11.21        Books  Â£0.00  94a958ea126cdcd5
# 29           Â£11.23        Books  Â£0.00  1e264c677d4ee4ae
# ..               ...          ...     ...               ...
# 45           Â£15.42        Books  Â£0.00  3d250ab0f12be445
# 46           Â£19.27        Books  Â£0.00  720c36b2bee4692e
# 47           Â£15.08        Books  Â£0.00  abbb492978ff656d
# 48           Â£11.05        Books  Â£0.00  f701fae56b645ef7
# 49           Â£11.33        Books  Â£0.00  c4182bdb53e2459a
# 50           Â£16.23        Books  Â£0.00  59a8ae019b64f2a7
# 51           Â£15.52        Books  Â£0.00  44f545727e704187
# 52           Â£17.49        Books  Â£0.00  b54d7416bb445989
# 53           Â£10.00        Books  Â£0.00  f36d24c309e87e5b
# 54           Â£17.21        Books  Â£0.00  f2c8f4b4c94d5c5c
# 55           Â£16.81        Books  Â£0.00  45033bdf3d9ed158
# 56           Â£13.73        Books  Â£0.00  31f5bbf4974d29c9
# 57           Â£19.67        Books  Â£0.00  5de4baa88061a77a
# 58           Â£12.75        Books  Â£0.00  869d20b3b8128230
# 59           Â£13.03        Books  Â£0.00  c6bf14cb901c63ac
# 60           Â£14.57        Books  Â£0.00  510832818edb6fbc
# 61           Â£12.91        Books  Â£0.00  28921443f052bea6
# 62           Â£19.07        Books  Â£0.00  2ef5dc7e278e562a
# 63           Â£10.79        Books  Â£0.00  621e2c310cec8d32
# 64           Â£15.36        Books  Â£0.00  ed813a848580ba50
# 65           Â£15.28        Books  Â£0.00  81372abc86f65c79
# 66           Â£14.08        Books  Â£0.00  5dbd6ec4e154ad2f
# 67           Â£12.86        Books  Â£0.00  6fa3ea52c8e31e06
# 68           Â£11.64        Books  Â£0.00  c0db71f6bb14db11
# 69           Â£18.51        Books  Â£0.00  09d26b5f819c6a36
# 70           Â£19.69        Books  Â£0.00  9c96cd1329fbd82d
# 71           Â£12.34        Books  Â£0.00  b78deb463531d078
# 72           Â£12.29        Books  Â£0.00  4280ac3eab57aa5d
# 73           Â£19.18        Books  Â£0.00  29fc016c459aeb14
# 74           Â£16.97        Books  Â£0.00  19fec36a1dfb4c16
#
#                                           Description Rating  \
# 0   Aaron Ledbetterâs future had been planned ou...   Five
# 1   In The Four Agreements, don Miguel Ruiz reveal...   Five
# 2   A page-turning novel that is also an explorati...   Five
# 3   More than thirty-five years ago, when the weat...   Four
# 4   Every summer, Rose goes with her mom and dad t...   Four
# 5   On a searing summer Friday, Eddie Chapman has ...   Five
# 6   THE LONG-AWAITED STORY OF FANGIRLS TAKING ON T...   Five
# 7   Just as Annie and Liam are busy making plans t...   Five
# 8   NEW HORROR SERIES FROM THE WALKING DEAD CREATO...   Four
# 9   Cecilia Granata grew up cooking with her famil...   Four
# 10  Caleb Stone was raised on the Upper East Side,...   Four
# 11  Ben 10 and Big Hero 6 creator Steven T. Seagle...   Four
# 12  NEW YORK TIMES BESTSELLERWALL STREET JOURNAL B...   Five
# 13  This is an alternate cover edition for ISBN 06...   Four
# 14  Katy Lewis has it all: a sports reporting job ...   Four
# 15  Following the success of their anthology Poems...   Four
# 16  They call me a slut. Maybe I am.Sometimes I do...   Five
# 17  This masterpiece of modern comics storytelling...   Five
# 18  A widely admired writer on religion celebrates...   Five
# 19  The fantastical tale of a young girl chasing h...   Five
# 20  Superman is going through some changes. First,...   Five
# 21  In the latest installment of the phenomenally ...   Five
# 22  In a kingdom by the seaâ¦In a secret world wh...   Five
# 23  A breakneck race against time...and an implaca...   Four
# 24  This is a book I wrote. Because I wrote it, I ...   Five
# 25  As far back as the fifth century BCE Pherecyde...   Five
# 26  From the winner of the National Book Award and...   Four
# 27  There are secrets you share, and secrets you h...   Four
# 28  Dear Mr. Knightley is a contemporary epistolar...   Five
# 29  The Mortal War is over, and sixteen-year-old C...   Four
# ..                                                ...    ...
# 45  The Collected Poems of W. B. Yeats includes al...   Five
# 46  "It is a truth universally acknowledged, that ...   Four
# 47  When orphaned Mary Lennox comes to live at her...   Four
# 48  The Power Greens Cookbook presents 140 delicio...   Five
# 49  The Darkest Corners is a psychological thrille...   Five
# 50  For years, Grace has watched the wolves in the...   Five
# 51  Just know from the start that it wasnât supp...   Five
# 52  Like lightning/you strike/fast and free/legs z...   Five
# 53  Katherine V thought boys were gross Katherine ...   Five
# 54  With A Feast for Crows, Martin delivers the lo...   Four
# 55  Americans have always loved guns. This special...   Four
# 56  An engrossing and thought provoking novel that...   Five
# 57  The year is 1945. Claire Randall, a former com...   Five
# 58  Never trust your heart to the New York Times b...   Four
# 59  The international bestseller that inspired a m...   Four
# 60  Cinder, the cyborg mechanic, returns in the se...   Four
# 61  Augusten Burroughs is the author of the bestse...   Four
# 62  In the year 2044, reality is an ugly place. Th...   Four
# 63  âDo you like green eggs and ham?â asks Sam...   Four
# 64  When unworldly student Anastasia Steele first ...   Five
# 65  INSTANT NEW YORK TIMES BESTSELLER "Wildly ente...   Five
# 66  Bennie is an aging former punk rocker and reco...   Five
# 67  Also see: Alternate Cover Editions for this IS...   Four
# 68  A family with an ancient curse...And the girl ...   Five
# 69  "Y" is none other than unemployed escape artis...   Four
# 70  An unlikely bond is forged between three men f...   Five
# 71  A chilling psychological thriller about a marr...   Five
# 72  Eighteen years ago your baby daughter was snat...   Five
# 73  Monday 27 Januaryâ7:15 a.m. Hurrah! The wild...   Four
# 74  In Englandâs Regency era, manners and elegan...   Five
#
#                                                 Title
# 0                                         Set Me Free
# 1   The Four Agreements: A Practical Guide to Pers...
# 2                                      Sophie's World
# 3             Untitled Collection: Sabbath Poems 2014
# 4                                     This One Summer
# 5                                              Thirst
# 6   Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Pr...
# 7    Princess Between Worlds (Wide-Awake Princess #5)
# 8   Outcast, Vol. 1: A Darkness Surrounds Him (Out...
# 9   Mama Tried: Traditional Italian Cooking for th...
# 10                 First and First (Five Boroughs #3)
# 11                                      Camp Midnight
# 12  The Third Wave: An Entrepreneurâs Vision of ...
# 13                                       The Stranger
# 14                           Something More Than This
# 15                    Poems That Make Grown Women Cry
# 16                                         Dark Notes
# 17           Batman: The Dark Knight Returns (Batman)
# 18                     Agnostic: A Spirited Manifesto
# 19                  Walt Disney's Alice in Wonderland
# 20  Superman Vol. 1: Before Truth (Superman by Gen...
# 21              Old School (Diary of a Wimpy Kid #10)
# 22              Lady Midnight (The Dark Artifices #1)
# 23                          I Am Pilgrim (Pilgrim #1)
# 24  Hyperbole and a Half: Unfortunate Situations, ...
# 25                               Greek Mythic History
# 26  Far & Away: Places on the Brink of Change: Sev...
# 27                               Eight Hundred Grapes
# 28                                 Dear Mr. Knightley
# 29  City of Fallen Angels (The Mortal Instruments #4)
# ..                                                ...
# 45  The Collected Poems of W.B. Yeats (The Collect...
# 46                                Pride and Prejudice
# 47                                  The Secret Garden
# 48  The Power Greens Cookbook: 140 Delicious Super...
# 49                                The Darkest Corners
# 50              Shiver (The Wolves of Mercy Falls #1)
# 51                                  Kill the Boy Band
# 52                                             Booked
# 53                         An Abundance of Katherines
# 54      A Feast for Crows (A Song of Ice and Fire #4)
# 55  The Gunning of America: Business and the Makin...
# 56                                         Some Women
# 57                           Outlander (Outlander #1)
# 58                    Night Shift (Night Shift #1-20)
# 59  The Elegant Universe: Superstrings, Hidden Dim...
# 60                  Scarlet (The Lunar Chronicles #2)
# 61                              Running with Scissors
# 62                                   Ready Player One
# 63           Green Eggs and Ham (Beginner Books B-16)
# 64               Fifty Shades Freed (Fifty Shades #3)
# 65  Disrupted: My Misadventure in the Start-Up Bubble
# 66                        A Visit from the Goon Squad
# 67                             New Moon (Twilight #2)
# 68           Fruits Basket, Vol. 2 (Fruits Basket #2)
# 69  Y: The Last Man, Vol. 1: Unmanned (Y: The Last...
# 70                                    The Zombie Room
# 71                                    The Silent Wife
# 72                                  The Girl You Lost
# 73              The Edge of Reason (Bridget Jones #2)
# 74  A Spy's Devotion (The Regency Spies of London #1)
#
# [75 rows x 10 columns]

# %% [markdown]
# ## Comment Threads
#
# Analyzing conversations in on-line communities is a popular way to study human interactions. One incarnation of these conversations are found in comment threads. These threads consist of back-and-forth interactions between users. These conversations are structured as *trees*, consisting of posts and their replies (this is likely, at least in part, a consequence of being structured as HTML, which is tree-based).
#
# To analyze these conversations efficiently, it's often needed to translate them to a *tabular format*. To do this requires making some design choices, as trees are naturally a *nested* data structure, whereas tables are *flat*.
#
# Oftentimes you will find already flattened data in csv formats (e.g. when someone else does the scraping). For example, a comment thread that originally looked like this:
#
# ---
# * post_id1 (user1) text1
#     * post_id2 (user2) reply_text2
#     * post_id3 (user3) reply_text3
# * post_id4 (user2) text4
#     * post_id5 (user4) reply_text5
# ---
#
# Is stored in CSV format like this:
#
# |post_id|reply_to|user|text|
# |---|---|---|---|
# |post_id1|`NaN`|user1|text1|
# |post_id2|post_id1|user2|reply_text2|
# |post_id3|post_id1|user3|reply_text3|
# |post_id4|`NaN`|user2|text4|
# |post_id5|post_id4|user4|reply_text5|
#
#
# When you have naturally tree-structured data stored in tabular format, you often need to partially 'undo' the above flattening transformation to answer questions about the data. For example, you may ask questions like:
# 1. How engaging is a given comment?
# 2. How many different people are actively engaged in a comment thread?
# 3. Is a flame-war occurring in a given comment thread?
#
# **Question 5**
#
# Assuming you are given comment threads stored in DataFrames as specified above, you want to calculate the following features (reflecting the above questions):
#
# 1. For each comment, how many replies is it from a top-level post? (i.e. what is its depth?).
#     * Create a function `depth` that takes in a dataframe like the one above and returns a series of depths.
# 2. For each comment, how many comments has it generated in reply?
#     * Create a function `descendants` that takes in a dataframe like the one above and returns the total number of comments that each comment has generated in reply (this includes replies of the replies).
# 3. For each comment, how many distinct users have responded to it?
#     * Create a function `distinct_descendants` that takes in a dataframe like the one above and returns the total number of distinct users that have replied to each comment.
#
# From these attributes, you can analyze interesting statistics on the interactions between people on a comment thread. Interesting observations can also come out of comparing these attributes to the content of the comment text.

# %%
# path to sample data
comments_path = os.path.join('data', 'comments.csv')
comments = pd.read_csv(comments_path, sep='|')
comments

# %% [markdown]
# ***Congratulations, you're done with the homework***
#
# Now, run your doctests and upload hw06.py to GradeScope.¶
